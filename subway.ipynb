# %% [markdown]
# <a href="https://colab.research.google.com/github/RIPavicii01/2025_1_BigData/blob/main/subway.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url = 'http://openapi.seoul.go.kr:8088/414d424556746f7036397a5a414f4f/json/SebcCollegeInfoKor/1/100//json/CardSubwayStatsNew/1/5/20220301'

# %%
response = requests.get(url)
print(response.content)
# Out:
# b'{"SebcCollegeInfoKor":{"list_total_count":64,"RESULT":{"CODE":"INFO-000","MESSAGE":"\xec\xa0\x95\xec\x83\x81 \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4"},"row":[{"MAIN_KEY":"BE_LiST23-0034","YEAR":"2013","CATE1_NAME":"\xec\x9d\xbc\xeb\xb0\x98\xeb\x8c\x80\xed\x95\x99","NAME_KOR":"\xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c\xeb\xa6\xbd\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90","BRANCH":"\xeb\xb3\xb8\xea\xb5\x90","STATE":"\xea\xb8\xb0\xec\xa1\xb4","TYPE":"\xea\xb3\xb5\xeb\xa6\xbd","POSTCODE":"","ADD_KOR":"\xec\x84\x9c\xec\x9a\xb8 \xeb\x8f\x99\xeb\x8c\x80\xeb\xac\xb8\xea\xb5\xac \xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c\xeb\xa6\xbd\xeb\x8c\x80\xeb\xa1\x9c 163 (\xec\xa0\x84\xeb\x86\x8d\xeb\x8f\x99 90\xeb\xb2\x88\xec\xa7\x80) ","ADD_KOR_ROAD":"","H_KOR_CITY":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c","H_KOR_GU":"\xeb\x8f\x99\xeb\x8c\x80\xeb\xac\xb8\xea\xb5\xac","H_KOR_DONG":"\xed\x9c\x98\xea\xb2\xbd2\xeb\x8f\x99","TEL":"02-6490-6114","FAX":"02
# ...

# %%
data = response.json()
data
# Out:
# {'SebcCollegeInfoKor': {'list_total_count': 64,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'MAIN_KEY': 'BE_LiST23-0034',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '서울시립대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '공립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 동대문구 서울시립대로 163 (전농동 90번지) ',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '동대문구',
#     'H_KOR_DONG': '휘경2동',
#     'TEL': '02-6490-6114',
#     'FAX': '02-2210-5576',
#     'HP': 'http://www.uos.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0035',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(3년제)',
#     'NAME_KOR': '서울여자간호대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서대문구 홍제3동 서울여자간호대학',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '홍제2동',
#     'TEL': '02-2287-1700',
#     'FAX': '02-395-8018',
# ...

# %%
import pandas as pd
temp = []

for d in data ['SebcCollegeInfoKor']['row']:
  temp.append(d)
uni = pd.DataFrame(temp)
uni
# Out:
#           MAIN_KEY  YEAR CATE1_NAME   NAME_KOR BRANCH   STATE   TYPE POSTCODE  \
# 0   BE_LiST23-0034  2013       일반대학    서울시립대학교     본교      기존     공립
# 1   BE_LiST23-0035  2013  전문대학(3년제)  서울여자간호대학교     본교      기존     사립
# 2   BE_LiST23-0036  2013       일반대학    서울여자대학교     본교      기존     사립
# 3   BE_LiST23-0037  2013  전문대학(2년제)      서일대학교     본교  학교명 변경     사립
# 4   BE_LiST23-0038  2013       일반대학     성공회대학교     본교      기존     사립
# ..             ...   ...        ...        ...    ...     ...    ...      ...
# 59  BE_LiST23-0029  2013       교육대학    서울교육대학교     본교      기존     국립
# 60  BE_LiST23-0030  2013       일반대학    서울기독대학교     본교      기존     사립
# 61  BE_LiST23-0031  2013       일반대학      서울대학교     본교      기존  국립대법인
# 62  BE_LiST23-0032  2013  사이버대학(대학)   서울디지털대학교     본교      기존     사립
# 63  BE_LiST23-0033  2013  사이버대학(대학)   서울사이버대학교     본교      기존     사립
#
#                                   ADD_KOR ADD_KOR_ROAD H_KOR_CITY H_KOR_GU  \
# ...

# %%
import requests

url = 'http://openapi.seoul.go.kr:8088/46487a6675746f703539496e596944/json/subwayStationMaster/1/100/'

response = requests.get(url)
print(response.content)
# Out:
# b'{"subwayStationMaster":{"list_total_count":909,"RESULT":{"CODE":"INFO-000","MESSAGE":"\xec\xa0\x95\xec\x83\x81 \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4"},"row":[{"BLDN_ID":"0150","BLDN_NM":"\xec\x84\x9c\xec\x9a\xb8\xec\x97\xad","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.556228","LOT":"126.972135"},{"BLDN_ID":"0151","BLDN_NM":"\xec\x8b\x9c\xec\xb2\xad","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.565715","LOT":"126.977088"},{"BLDN_ID":"0152","BLDN_NM":"\xec\xa2\x85\xea\xb0\x81","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.570161","LOT":"126.982923"},{"BLDN_ID":"0153","BLDN_NM":"\xec\xa2\x85\xeb\xa1\x9c3\xea\xb0\x80","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.570406","LOT":"126.991847"},{"BLDN_ID":"0154","BLDN_NM":"\xec\xa2\x85\xeb\xa1\x9c5\xea\xb0\x80","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT":"37.570926","LOT":"127.001849"},{"BLDN_ID":"0155","BLDN_NM":"\xeb\x8f\x99\xeb\x8c\x80\xeb\xac\xb8","ROUTE":"1\xed\x98\xb8\xec\x84\xa0","LAT"
# ...

# %%
data = response.json()
data
# Out:
# {'subwayStationMaster': {'list_total_count': 909,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'BLDN_ID': '0150',
#     'BLDN_NM': '서울역',
#     'ROUTE': '1호선',
#     'LAT': '37.556228',
#     'LOT': '126.972135'},
#    {'BLDN_ID': '0151',
#     'BLDN_NM': '시청',
#     'ROUTE': '1호선',
#     'LAT': '37.565715',
#     'LOT': '126.977088'},
#    {'BLDN_ID': '0152',
#     'BLDN_NM': '종각',
#     'ROUTE': '1호선',
#     'LAT': '37.570161',
#     'LOT': '126.982923'},
#    {'BLDN_ID': '0153',
#     'BLDN_NM': '종로3가',
#     'ROUTE': '1호선',
#     'LAT': '37.570406',
#     'LOT': '126.991847'},
#    {'BLDN_ID': '0154',
#     'BLDN_NM': '종로5가',
#     'ROUTE': '1호선',
#     'LAT': '37.570926',
#     'LOT': '127.001849'},
#    {'BLDN_ID': '0155',
#     'BLDN_NM': '동대문',
#     'ROUTE': '1호선',
#     'LAT': '37.571687',
#     'LOT': '127.01093'},
#    {'BLDN_ID': '0156',
#     'BLDN_NM': '신설동',
#     'ROUTE': '1호선',
#     'LAT': '37.576048',
#     'LOT': '127.024634'},
# ...

# %%
import pandas as pd
temp = []

for d in data ['subwayStationMaster']['row']:
  temp.append(d)
a = pd.DataFrame(temp)
a
# Out:
#    BLDN_ID BLDN_NM ROUTE        LAT         LOT
# 0     0150     서울역   1호선  37.556228  126.972135
# 1     0151      시청   1호선  37.565715  126.977088
# 2     0152      종각   1호선  37.570161  126.982923
# 3     0153    종로3가   1호선  37.570406  126.991847
# 4     0154    종로5가   1호선  37.570926  127.001849
# ..     ...     ...   ...        ...         ...
# 95    0406      오남   진접선     37.705   127.19281
# 96    0408   별내별가람   진접선   37.66778   127.11581
# 97    0409     당고개   4호선  37.670272  127.079066
# 98    0410      상계   4호선  37.660878  127.073572
# 99    0411      노원   4호선   37.65627  127.063276
#
# [100 rows x 5 columns]

# %%
import folium
folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
b = folium.Map(location=[37.448028, 127.169366])
b
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for n, row in a.iterrows():
    mk = folium.Marker(location=[row["LAT"], row["LOT"]],
                       popup=folium.Popup(row["BLDN_NM"], max_width=200))
    mk.add_to(b)
b
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium.plugins import MarkerCluster
mc = MarkerCluster().add_to(b)

for _, row in a.iterrows():
    folium.Marker(location=[row["LAT"], row["LOT"]],
                  popup=folium.Popup(row["BLDN_NM"], max_width=200)
                 ).add_to(mc)

b
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
